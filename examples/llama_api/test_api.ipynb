# %%
from openai import AsyncOpenAI

# %%
client = AsyncOpenAI(base_url="http://localhost:7776/v1", api_key="dummy-key")

# %%
l = await client.models.list()

# %%
# Cell 3: Use chat completions directly
async def get_completion(prompt):
    completion = await client.chat.completions.create(
        model="any-model-id",  # This is ignored by your server
        messages=[{"role": "user", "content": prompt}],
        tool_choice="auto",
        max_tokens=1000,
        stream=False
    )

    assistant_message = completion.choices[0].message

    return completion
    
# Cell 4: Test it
prompt = "What is the capital of France?"
completion = await get_completion(prompt)

# %%
completion
# Out:
# ChatCompletion(id='0039596697a9b8adc1aa88756b314455', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='The capital of France is Paris.', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None))], created=1742410783, model='/Users/frank/Library/Caches/tinygrad/downloads/llama3-1b-instruct/Llama-3.2-1B-Instruct-Q6_K.gguf', object='chat.completion', service_tier=None, system_fingerprint=None, usage=None)

# %%
# Cell 3: Use chat completions directly
async def get_completion(prompt):
    completion = await client.chat.completions.create(
        model="any-model-id",  # This is ignored by your server
        messages=[{"role": "user", "content": prompt}],
        tools=[
            {
                "type": "function",
                "function": {
                    "name": "get_capital",
                    "description": "Get the capital of a country",
                    "parameters": {
                    "properties": {
                        "country": {
                        "type": "string"
                        }
                    }
                }
                }
            }
        ],
        tool_choice="auto",
        max_tokens=1000,
        stream=False
    )

    assistant_message = completion.choices[0].message

    return completion
    
# Cell 4: Test it
prompt = "What is the capital of France?"
completion = await get_completion(prompt)

# %%
completion
# Out:
# ChatCompletion(id='chatcmpl-690832dc4947aeeac71d3b8a5077c3e1', choices=[Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role=None, annotations=None, audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='tool_call_08dc9fcd-c20d-4911-92b6-935f93dab173', function=Function(arguments='{"country": "\'France\'"}', name='get_capital'), type='function', index=0)]))], created=1742410806, model='/Users/frank/Library/Caches/tinygrad/downloads/llama3-1b-instruct/Llama-3.2-1B-Instruct-Q6_K.gguf', object='chat.completion', service_tier=None, system_fingerprint='exo_v1.5', usage=None)

# %%
from openai import OpenAI

def stream_chat_response(prompt):
    # Initialize client
    client = OpenAI(base_url="http://localhost:7776/v1", api_key="dummy-key")
    
    # Create a streaming completion
    stream = client.chat.completions.create(
        model="any-model-id",  # This is ignored by your local server
        messages=[{"role": "user", "content": prompt}],
        max_tokens=1000,
        stream=True  # Enable streaming
    )
    
    # Process and print the stream in real-time
    full_response = ""
    for chunk in stream:
        if chunk.choices and chunk.choices[0].delta.content is not None:
            content_chunk = chunk.choices[0].delta.content
            print(content_chunk, end="", flush=True)  # Print incrementally
            full_response += content_chunk
    
    return full_response

# Example usage - just run this in your cell
prompt = "Write a 4-line poem about artificial intelligence."
stream_chat_response(prompt)
# Out:
# Silicon minds that learn and grow,
# Processing thoughts as they flow.
# Artificial minds that think and sway,
# Will change the world in a digital way.
# 'Silicon minds that learn and grow,\nProcessing thoughts as they flow.\nArtificial minds that think and sway,\nWill change the world in a digital way.'

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("/Users/frank/Library/Caches/tinygrad/downloads/llama3-1b-instruct/")

# %%
tokenizer.decode(tokenizer.encode('Hello, world!'))
# Out:
# '<|begin_of_text|>Hello, world!'

# %%
tokenizer.encode('<|eot_id|>')
# Out:
# [128000, 128009]

# %%
tokenizer.eos_token
# Out:
# '<|end_of_text|>'
